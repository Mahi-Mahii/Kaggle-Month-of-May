# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\Intellipaat\kegal datasets\playground-series-s4e5 May\train.csv")
data.drop(columns=['id'],inplace = True)
data
# Out:
#          MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                       5                   8                5              8
# 1                       6                   7                4              4
# 2                       6                   5                6              7
# 3                       3                   4                6              5
# 4                       5                   3                2              6
# ...                   ...                 ...              ...            ...
# 1117952                 3                   3                4             10
# 1117953                 2                   2                4              3
# 1117954                 7                   3                9              4
# 1117955                 7                   3                3              7
# 1117956                 4                   5                6              9
#
# ...

# %%
org_data = pd.read_csv(r"D:\Intellipaat\kegal datasets\playground-series-s4e5 May\flood.csv")
org_data
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                     3                   8                6              6
# 1                     8                   4                5              7
# 2                     3                  10                4              1
# 3                     4                   4                2              7
# 4                     3                   7                5              2
# ...                 ...                 ...              ...            ...
# 49995                 3                   7                4              7
# 49996                 3                  10                3              8
# 49997                 4                   4                5              7
# 49998                 4                   5                4              4
# 49999                 4                   5                6              3
#
# ...

# %%
df = pd.concat([data,org_data],axis = 0,ignore_index=True)
df
# Out:
#          MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                       5                   8                5              8
# 1                       6                   7                4              4
# 2                       6                   5                6              7
# 3                       3                   4                6              5
# 4                       5                   3                2              6
# ...                   ...                 ...              ...            ...
# 1167952                 3                   7                4              7
# 1167953                 3                  10                3              8
# 1167954                 4                   4                5              7
# 1167955                 4                   5                4              4
# 1167956                 4                   5                6              3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167957 entries, 0 to 1167956
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   MonsoonIntensity                 1167957 non-null  int64
#  1   TopographyDrainage               1167957 non-null  int64
#  2   RiverManagement                  1167957 non-null  int64
#  3   Deforestation                    1167957 non-null  int64
#  4   Urbanization                     1167957 non-null  int64
#  5   ClimateChange                    1167957 non-null  int64
#  6   DamsQuality                      1167957 non-null  int64
#  7   Siltation                        1167957 non-null  int64
#  8   AgriculturalPractices            1167957 non-null  int64
#  9   Encroachments                    1167957 non-null  int64
#  10  IneffectiveDisasterPreparedness  1167957 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# for col_names in df.columns:
#     plt.figure(figsize=(2,3))
#     plt.boxplot(df[col_names])
#     plt.xlabel(col_names)
#     plt.ylabel('count')
#     plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()
std
# Out:
# StandardScaler()

# %%
x= df.iloc[:,:-1]
x.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 5                   8                5              8
# 1                 6                   7                4              4
# 2                 6                   5                6              7
# 3                 3                   4                6              5
# 4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
y = df.iloc[:,-1:]
y.head()
# Out:
#    FloodProbability
# 0             0.445
# 1             0.450
# 2             0.530
# 3             0.535
# 4             0.415

# %%
for i in x.columns:
    x[i] = std.fit_transform(x[[i]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array([[0.53884649],
#        [0.4717092 ],
#        [0.50519072],
#        ...,
#        [0.44358734],
#        [0.46612406],
#        [0.46607626]])

# %%
r2_score(y_test,pred)
# Out:
# 0.8477670019560686

# %%
test_data = pd.read_csv(r"D:\Intellipaat\kegal datasets\playground-series-s4e5 May\test.csv")
test= test_data.drop(columns=['id'])
test
# Out:
#         MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                      4                   6                3              5
# 1                      4                   4                2              9
# 2                      1                   3                6              5
# 3                      2                   4                4              6
# 4                      6                   3                2              4
# ...                  ...                 ...              ...            ...
# 745300                 5                   4                8              3
# 745301                 4                   4                2             12
# 745302                 5                   7                9              5
# 745303                 4                   7                6              3
# 745304                 4                   2                5              3
#
# ...

# %%
for i in test.columns:
    test[i] = std.fit_transform(test[[i]])

# %%
test
# Out:
#         MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0              -0.445272            0.510818        -0.946087       0.026267
# 1              -0.445272           -0.444239        -1.428778       1.975015
# 2              -1.904208           -0.921767         0.501985       0.026267
# 3              -1.417896           -0.444239        -0.463396       0.513454
# 4               0.527351           -0.921767        -1.428778      -0.460920
# ...                  ...                 ...              ...            ...
# 745300          0.041040           -0.444239         1.467367      -0.948107
# 745301         -0.445272           -0.444239        -1.428778       3.436575
# 745302          0.041040            0.988347         1.950057       0.026267
# 745303         -0.445272            0.988347         0.501985      -0.948107
# 745304         -0.445272           -1.399296         0.019295      -0.948107
#
# ...

# %%
predictions = model.predict(test)
predictions
# Out:
# array([[0.57283694],
#        [0.45522608],
#        [0.45471849],
#        ...,
#        [0.62340096],
#        [0.55052503],
#        [0.51128107]])

# %%
if predictions.ndim > 1:
    predictions = predictions.flatten()

# %%
len(test_data['id'])
# Out:
# 745305

# %%
len(predictions)
# Out:
# 745305

# %%
if predictions.ndim > 1:
    predictions = predictions.flatten()

# %%
submission_df = pd.DataFrame({'id': test_data['id'], 'FloodProbability' : predictions})
submission_df
# Out:
#              id  FloodProbability
# 0       1117957          0.572837
# 1       1117958          0.455226
# 2       1117959          0.454718
# 3       1117960          0.466031
# 4       1117961          0.466059
# ...         ...               ...
# 745300  1863257          0.477077
# 745301  1863258          0.449357
# 745302  1863259          0.623401
# 745303  1863260          0.550525
# 745304  1863261          0.511281
#
# [745305 rows x 2 columns]

# %%
submission_df.to_csv('submission_linear.csv', index=False)
